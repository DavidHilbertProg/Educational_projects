# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr

# %%
data = pd.read_csv('price.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   20 non-null     int64
#  1   Value   20 non-null     int64
# dtypes: int64(2)
# memory usage: 452.0 bytes

# %%
# Вычисление корреляции и p-значения
r, p_value = pearsonr(data['Price'], data['Value'])

print(f"Коэффициент корреляции: {r}")
print(f"P-значение: {p_value}")
# Out:
# Коэффициент корреляции: 0.6809042355030791
# P-значение: 0.0009503846229577792

# %%
# Построение диаграммы рассеяния
plt.scatter(data['Price'], data['Value'])
plt.xlabel('Price')
plt.ylabel('Value')
plt.title('Scatter Plot')
plt.show()
